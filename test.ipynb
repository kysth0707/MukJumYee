# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img = cv.imread(r'testimg.png', cv.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %%
plt.imshow(np.random.normal(0.0, 0.1, (32, 32)), cmap='gray')

# %%
img.shape, np.random.normal(0.0, 0.1, (32, 32)).shape
# Out:
# ((32, 32), (32, 32))

# %%
plt.imshow(img / 255. + np.random.normal(0.0, 0.1, (32, 32)), cmap='gray')

# %%
plt.imshow(np.random.randint(0, 2, (32, 32)) * 1., cmap='gray')

# %%
temp = img / 255.

for _ in range(2):
	temp[np.random.randint(0, 32),np.random.randint(0, 32)] = 0.0
plt.imshow(temp, cmap='gray')
